# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('community_0_perplexity.csv')

# %%
data = pd.read_csv('community_0_coherences_perplexities_posts.csv')

topic_nums = list(np.array(data['topic_num'].tolist()))
coherences = list(np.array(data['coherence'].tolist()))
perplexities = list(np.array(data['perplexity'].tolist()))

# %%
plt.plot(topic_nums, coherences)
plt.show()

# %%
plt.plot(topic_nums, perplexities)
plt.show()

# %%
# community 0 posts topic_num = 50

# %%
# community 1 topic_num = 25

# %%
data = pd.read_csv('community_1_coherences_perplexities_posts.csv')

topic_nums = list(np.array(data['topic_num'].tolist()))
coherences = list(np.array(data['coherence'].tolist()))
perplexities = list(np.array(data['perplexity'].tolist()))

# %%
plt.plot(topic_nums, coherences)
plt.show()

# %%
plt.plot(topic_nums, perplexities)
plt.show()

# %%
# community 1 topic_num posts = 25

# %%
data = pd.read_csv('community_7_coherences_perplexities_posts.csv')

topic_nums = list(np.array(data['topic_num'].tolist()))
coherences = list(np.array(data['coherence'].tolist()))
perplexities = list(np.array(data['perplexity'].tolist()))

# %%
plt.plot(topic_nums, coherences)
plt.show()

# %%
plt.plot(topic_nums, perplexities)
plt.show()

# %%
# community 7 topic_num posts = 20

# %%
coherences = [-1.8412221287956219,-1.9523670045541022,-1.945127278069099,-2.1510123352683705,-2.2036021264971026,-2.1888136110912293,-2.3025295332606674,-2.4477154295266765,-2.251156912130355,-2.20854248266338,-2.2914103434457638,-2.1520841351488254,-2.303114961254932,-2.374741967444836,-2.841546531408976,-3.56819765512511,-3.45106880099529,-3.5691502977452463,-3.2294369636291793,-2.774340219140256]
perplexities = [-7.523623485874976,-7.617861549606638,-7.706906570942874,-7.787143500231541,-7.882120790340039,-7.9776098216589535,-8.013082323164273,-8.16001668268534,-8.23092028261082,-8.25588195027199,-8.40946419354084,-8.42494869273732,-8.587604513506802,-8.710313947090315,-8.801168839904724,-8.904378736068931,-9.008242119914849,-9.095963979343354,-9.179487714639992,-9.239083338992238]

# %%
plt.plot(topic_nums, coherences)
plt.show()

# %%
plt.plot(topic_nums, perplexities)
plt.show()

# %%
# community 0 topic_num = 45
