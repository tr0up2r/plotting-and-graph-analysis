# %%
# For using custom module.
import sys
sys.path.append('../custom_library')

# %%
import numpy as np
import pandas as pd 
import connect_to_db as cn
import yake

# %%
def extract_keywords(doc):
    kw_extractor = yake.KeywordExtractor()
    language = "en"
    max_ngram_size = 1
    deduplication_threshold = 0.9
    numOfKeywords = 5
    custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
    
    keyword_list = []
    for text in doc:
        keywords = custom_kw_extractor.extract_keywords(text)
        for kw in keywords:
            if kw[0].isalnum() and 'â' not in kw[0]:
                keyword_list.append(kw[0].lower())
        
    return keyword_list

# %%
def save_keywords(table_name, author, degree, count, remove_sw):
    doc = []

    if degree == 'outdegree':
        sql = f"select distinct body from comments where author='{author}' and link_key = parent_key and is_valid_author=1 and is_valid=1;"
    else:
        sql = 'test'
    result_df = cn.select_query_result_to_df(sql)
    if not result_df.empty:
        if degree == 'outdegree':
            bodies = np.array(result_df['body'].astype(str).values.tolist())
            doc.extend(bodies)

    return extract_keywords(doc)

# %%
sql = "select node_id from nodes where top_k_outdegree=0.1 limit 100;"
result_df = cn.select_query_result_to_df(sql)
hub_users = list(np.array(result_df['node_id'].values.tolist()))
counts = list(np.array(result_df['outdegree'].values.tolist()))

keywords_list = []

for user, count in zip(hub_users, counts):
    keywords_list.append(save_keywords('nodes', user, 'outdegree', count, True))

# %%
key_set = list(set(list(sum(keywords_list, []))))
counts = [0] * len(key_set)
print(len(counts), len(key_set))

all_keywords = list(sum(keywords_list, []))

for i in range(len(all_keywords)):
    for j in range(len(key_set)):
        if all_keywords[i] == key_set[j]:
            counts[j] += 1
            break
# Out:
# 8005 8005

# %%
print(list(zip(key_set, counts)))
# Out:
# [('meme', 4), ('œthis', 2), ('genetic', 7), ('exausting', 1), ('shitty', 22), ('permanent', 9), ('therapeutic', 2), ('lowering', 1), ('lots', 25), ('leads', 5), ('catcalled', 1), ('immigration', 1), ('dads', 1), ('smell', 5), ('headspace', 5), ('immensely', 1), ('disregulation', 1), ('action', 7), ('answering', 4), ('enemy', 2), ('odsp', 1), ('getdisciplined', 3), ('tenth', 1), ('russell', 1), ('coast', 1), ('experimented', 1), ('feared', 1), ('dark', 14), ('bullied', 6), ('cherries', 1), ('nighttime', 2), ('counsellors', 1), ('momentary', 1), ('daughter', 4), ('sarcastic', 1), ('flex', 2), ('case', 38), ('sterilized', 1), ('type', 22), ('brush', 3), ('freshman', 3), ('metabolic', 1), ('ditch', 2), ('compliant', 3), ('images', 1), ('winter', 3), ('labyrinth', 1), ('zombiefication', 1), ('pimples', 1), ('faded', 1), ('resource', 1), ('unhappiness', 1), ('joint', 1), ('social', 113), ('graduate', 3), ('exasperating', 1), ('innuendo', 1), ('cna', 1), ('sorority', 1), ('minute', 6), ('phone', 19), ('pent', 1), ('hypnosis', 1), ('grounded', 2), ('hourly', 1), ('fixed', 4), ('conclusions', 1), ('dishwashing', 1), ('raisedbyborderlines', 1), ('nutrition', 1), ('embracing', 1), ('looked', 6), ('threaten', 1), ('cozyplaces', 1), ('panicking', 1), ('activated', 1), ('cured', 7), ('savor', 1), ('hotline', 6), ('clerk', 1), ('visiting', 2), ('arrived', 2), ('isf', 18), ('lock', 1), ('attacked', 5), ('internalized', 1), ('belittling', 1), ('singh', 1), ('plug', 1), ('destroyed', 4), ('emotions', 54), ('chemdah', 1), ('guitar', 2), ('declined', 2), ('harnessed', 1), ('œhi', 1), ('christians', 1), ('occurs', 1), ('discourages', 1), ('hysterectomy', 1), ('hopes', 3), ('click', 8), ('definite', 1), ('bedwetting', 1), ('vices', 1), ('sentiment', 4), ('stormy', 1), ('strategy', 1), ('raped', 4), ('cod', 1), ('mmm', 1), ('wing', 1), ('original', 8), ('excess', 1), ('positive', 52), ('relieves', 1), ('destruction', 1), ('thirteen', 2), ('insightful', 3), ('paragraph', 2), ('accomplished', 4), ('camus', 2), ('blood', 12), ('direction', 4), ('tardive', 1), ('interpreted', 1), ('restless', 2), ('berserk', 1), ('continues', 1), ('fixable', 3), ('targets', 1), ('pragmatically', 1), ('demons', 10), ('screw', 3), ('testosterone', 2), ('motivated', 2), ('sports', 2), ('hunting', 2), ('truely', 1), ('lose', 37), ('surprised', 8), ('jones', 1), ('waaay', 1), ('aries', 1), ('positivity', 7), ('pencils', 1), ('lengths', 1), ('idk', 27), ('crippling', 1), ('courage', 10), ('reason', 72), ('shattering', 1), ('moing', 1), ('people', 980), ('things', 394), ('hold', 42), ('stored', 2), ('solitude', 2), ('kinder', 2), ('male', 11), ('compatibility', 1), ('onetime', 1), ('refuse', 3), ('stepsisters', 1), ('sci', 1), ('admire', 2), ('moods', 1), ('suck', 33), ('student', 8), ('denial', 4), ('fpss', 1), ('neurotic', 1), ('work', 279), ('teams', 1), ('dissociative', 2), ('sleepy', 6), ('australia', 1), ('large', 4), ('grieve', 11), ('youve', 1), ('soothing', 1), ('business', 7), ('painkillers', 2), ('extra', 3), ('limits', 1), ('sums', 2), ('connected', 4), ('compulsion', 5), ('alters', 4), ('endless', 3), ('client', 2), ('overstepping', 1), ('slides', 1), ('shops', 1), ('revocation', 1), ('surprises', 1), ('queen', 1), ('coconut', 1), ('father', 22), ('throat', 7), ('table', 3), ('msgs', 1), ('mustering', 1), ('iok', 1), ('overused', 1), ('make', 259), ('mozzie', 1), ('lighten', 2), ('left', 26), ('sedatives', 1), ('outbreaks', 1), ('rehab', 1), ('adhd', 7), ('dose', 18), ('counting', 2), ('literally', 40), ('bronchitis', 1), ('dumpster', 4), ('daydreamed', 1), ('rehumanizing', 1), ('degenerative', 1), ('minimizing', 1), ('pisses', 1), ('tunneling', 1), ('starving', 1), ('share', 29), ('victimless', 1), ('distressing', 1), ('creations', 1), ('intrusive', 6), ('intro', 1), ('pros', 1), ('weirdest', 1), ('days', 80), ('solid', 3), ('climbing', 1), ('artwork', 1), ('sink', 2), ('coordination', 1), ('chidl', 1), ('mine', 45), ('garden', 1), ('cheaper', 2), ('high', 48), ( ...

# %%
word_count_pair = []
for word, count in zip(key_set, counts):
    word_count_pair.append([word, count])

pair_dict = dict(word_count_pair)
sorted_pair_dict = sorted(pair_dict.items(), key = lambda item: item[1], reverse = True)

# %%
print(sorted_pair_dict[:50])
# Out:
# [('people', 980), ('feel', 891), ('good', 625), ('time', 578), ('talk', 484), ('hey', 458), ('life', 435), ('things', 394), ('yeah', 380), ('feeling', 351), ('anxiety', 304), ('hope', 288), ('love', 285), ('work', 279), ('day', 277), ('years', 269), ('sounds', 269), ('lot', 268), ('make', 259), ('thing', 257), ('happy', 247), ('hard', 245), ('bpd', 236), ('give', 236), ('meds', 222), ('find', 218), ('person', 217), ('man', 217), ('bad', 214), ('dont', 208), ('therapy', 198), ('friends', 196), ('symptoms', 184), ('depression', 183), ('therapist', 177), ('psychiatrist', 170), ('wanna', 169), ('stop', 164), ('friend', 161), ('trauma', 160), ('great', 158), ('dude', 154), ('back', 153), ('understand', 147), ('schizophrenia', 146), ('normal', 145), ('doctor', 143), ('parents', 141), ('long', 139), ('job', 136)]
