# %%
import pymysql.cursors
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import connect_to_db as cn
import matplotlib.ticker as mtick
from matplotlib.ticker import PercentFormatter

# %%
def normalization(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

# %%
def draw_multiple_cdf_normalize_y(np_result_list, title, colors, xlabel, legends, log_scale):
    filename = title + '.png'
    fig = plt.figure(figsize=(15,10))
    fig.set_facecolor('white')
    ax = fig.add_subplot()
    
    for np_result, color, legend in zip(np_result_list, colors, legends):
        sorted_data = np.sort(np_result)
        plt.step(sorted_data, normalization(np.arange(sorted_data.size)), label=legend, color=color)
        plt.xlabel(xlabel, fontsize=12)
        plt.title(title, fontsize=18)
        if log_scale:
            plt.xscale('symlog')
  
    plt.legend(fontsize=14)
    plt.savefig(filename, dpi=300)
    plt.show()

# %%
sql = 'select * from mentor;'
result_df = cn.select_query_result_to_df(sql)
result_df
# Out:
#                       author  comment_cnt  mentee_cnt average_is_score  \
# 0       _________________UWU            1           1       2.00000000
# 1        ______________Blank            1           1       2.00000000
# 2       _________-----------            1           1       3.00000000
# 3       _________ez_________            1           1       1.00000000
# 4              _______woohoo            1           1       1.00000000
# ...                      ...          ...         ...              ...
# 461352              Zzzzz315            1           1       1.00000000
# 461353              zzzzzima            2           2       2.00000000
# 461354      zzzzzsleepyzzzzz            2           2       1.50000000
# 461355           zzzzzzz____            2           2       1.00000000
# 461356           zzzzzzzzzz-            1           1       1.00000000
#
#        average_es_score comments_similarity posts_similarity is_score_entropy  \
# 0            2.00000000                None             None             0E-8
# 1            2.00000000                None             None             0E-8
# 2            1.00000000                None             None             0E-8
# 3            2.00000000                None             None             0E-8
# 4            2.00000000                None             None             0E-8
# ...                 ...                 ...              ...              ...
# 461352       3.00000000                None             None             0E-8
# 461353       2.00000000          0.16390613             0E-8             0E-8
# 461354       1.50000000          0.03616722       0.04416443       0.63092975
# 461355       2.00000000          0.23076793             0E-8             0E-8
# 461356       2.00000000                None             None             0E-8
#
#        es_score_entropy average_vote
# 0                  0E-8      1.00000
# 1                  0E-8      1.00000
# 2                  0E-8      1.00000
# 3                  0E-8      1.00000
# 4                  0E-8      3.00000
# ...                 ...          ...
# 461352             0E-8      1.00000
# 461353       0.63092975     13.00000
# 461354       0.63092975      1.50000
# 461355             0E-8      1.50000
# 461356             0E-8      6.00000
#
# [461357 rows x 10 columns]

# %%
sql2 = 'select * from mentor where comments_similarity >= 0;'
result_df2 = cn.select_query_result_to_df(sql2)
result_df2
# Out:
#                   author  comment_cnt  mentee_cnt average_is_score  \
# 0            _______ZERO           10          10       1.10000000
# 1          ______V______            6           6       1.33333333
# 2                _____0_            2           2       1.00000000
# 3              _____boop            7           7       1.28571429
# 4          _____els3sle-            8           7       1.25000000
# ...                  ...          ...         ...              ...
# 224401        ZzzzoZzzzo            3           3       1.66666667
# 224402        zzzztheday           11          11       1.54545455
# 224403          zzzzzima            2           2       2.00000000
# 224404  zzzzzsleepyzzzzz            2           2       1.50000000
# 224405       zzzzzzz____            2           2       1.00000000
#
#        average_es_score comments_similarity posts_similarity is_score_entropy  \
# 0            2.20000000          0.09195855       0.05160771       0.29590327
# 1            2.66666667          0.10136209       0.04694719       0.57938016
# 2            2.50000000          0.07903821       0.03580134             0E-8
# 3            2.85714286          0.15010499       0.02310080       0.54456845
# 4            1.87500000          0.13326611       0.04322288       0.51185951
# ...                 ...                 ...              ...              ...
# 224401       1.33333333          0.12780807       0.13645193       0.57938016
# 224402       2.18181818          0.11286962       0.03088349       0.82607422
# 224403       2.00000000          0.16390613             0E-8             0E-8
# 224404       1.50000000          0.03616722       0.04416443       0.63092975
# 224405       2.00000000          0.23076793             0E-8             0E-8
#
#        es_score_entropy average_vote
# 0            0.81734542      6.60000
# 1            0.57938016      1.16667
# 2            0.63092975      2.50000
# 3            0.37330396      1.71429
# 4            0.88685951      2.00000
# ...                 ...          ...
# 224401       0.57938016      2.33333
# 224402       0.94318878      3.36364
# 224403       0.63092975     13.00000
# 224404       0.63092975      1.50000
# 224405             0E-8      1.50000
#
# [224406 rows x 10 columns]

# %%
sql3 = 'select * from mentor where posts_similarity >= 0;'
result_df3 = cn.select_query_result_to_df(sql3)
result_df3
# Out:
#                   author  comment_cnt  mentee_cnt average_is_score  \
# 0            _______ZERO           10          10       1.10000000
# 1          ______V______            6           6       1.33333333
# 2                _____0_            2           2       1.00000000
# 3              _____boop            7           7       1.28571429
# 4          _____els3sle-            8           7       1.25000000
# ...                  ...          ...         ...              ...
# 220836        ZzzzoZzzzo            3           3       1.66666667
# 220837        zzzztheday           11          11       1.54545455
# 220838          zzzzzima            2           2       2.00000000
# 220839  zzzzzsleepyzzzzz            2           2       1.50000000
# 220840       zzzzzzz____            2           2       1.00000000
#
#        average_es_score comments_similarity posts_similarity is_score_entropy  \
# 0            2.20000000          0.09195855       0.05160771       0.29590327
# 1            2.66666667          0.10136209       0.04694719       0.57938016
# 2            2.50000000          0.07903821       0.03580134             0E-8
# 3            2.85714286          0.15010499       0.02310080       0.54456845
# 4            1.87500000          0.13326611       0.04322288       0.51185951
# ...                 ...                 ...              ...              ...
# 220836       1.33333333          0.12780807       0.13645193       0.57938016
# 220837       2.18181818          0.11286962       0.03088349       0.82607422
# 220838       2.00000000          0.16390613             0E-8             0E-8
# 220839       1.50000000          0.03616722       0.04416443       0.63092975
# 220840       2.00000000          0.23076793             0E-8             0E-8
#
#        es_score_entropy average_vote
# 0            0.81734542      6.60000
# 1            0.57938016      1.16667
# 2            0.63092975      2.50000
# 3            0.37330396      1.71429
# 4            0.88685951      2.00000
# ...                 ...          ...
# 220836       0.57938016      2.33333
# 220837       0.94318878      3.36364
# 220838       0.63092975     13.00000
# 220839       0.63092975      1.50000
# 220840             0E-8      1.50000
#
# [220841 rows x 10 columns]

# %%
result_df4 = pd.read_csv('random_similarity_2.csv')
print(result_df4)
# Out:
#      random_comments_similarity  random_posts_similarity
# 0                      0.000000                 0.000000
# 1                      0.170055                 0.000000
# 2                      0.072244                 0.000000
# 3                      0.033894                 0.078745
# 4                      0.071075                 0.000000
# ..                          ...                      ...
# 995                    0.199084                 0.000000
# 996                    0.084693                 0.000000
# 997                    0.079526                 0.000000
# 998                    0.000000                 0.059930
# 999                    0.181773                 0.000000
#
# [1000 rows x 2 columns]

# %%
result_df5 = pd.read_csv('random_similarity_4.csv')
print(result_df5)
# Out:
#      random_comments_similarity  random_posts_similarity
# 0                      0.096070                 0.021508
# 1                      0.042308                 0.046670
# 2                      0.113791                 0.034269
# 3                      0.090947                 0.023521
# 4                      0.070478                 0.021279
# ..                          ...                      ...
# 995                    0.088427                 0.025323
# 996                    0.057559                 0.000000
# 997                    0.066319                 0.000000
# 998                    0.136684                 0.000000
# 999                    0.007605                 0.010563
#
# [1000 rows x 2 columns]

# %%
sql4 = 'select * from nodes;'
result_df6 = cn.select_query_result_to_df(sql4)
result_df6
# Out:
#                      node_id  indegree  outdegree top_k_indegree  \
# 0       _________________UWU         2          1         100.00
# 1        ______________Blank         0          1         100.00
# 2       _________-----------         0          1         100.00
# 3       _________ez_________         0          1         100.00
# 4                ________hey         1          0         100.00
# ...                      ...       ...        ...            ...
# 691421           zzzzzzzzzra         5          0         100.00
# 691422           zzzzzzzzzz-         0          1         100.00
# 691423         ZZZZZzzzzzxzx         1          0         100.00
# 691424      zzzzzzzzzzzsdasd         2          0         100.00
# 691425  zzzzzzzzzzzzz-------         4          0         100.00
#
#        top_k_outdegree  community_id_fastgreedy_is  \
# 0               100.00                           0
# 1               100.00                           0
# 2               100.00                           1
# 3               100.00                           2
# 4               100.00                           0
# ...                ...                         ...
# 691421          100.00                           3
# 691422          100.00                           0
# 691423          100.00                           0
# 691424          100.00                       10667
# 691425          100.00                          32
#
#         community_id_fastgreedy_es  community_id_leiden_is  \
# 0                                0                       0
# 1                                0                       1
# 2                                1                       3
# 3                                2                       4
# 4                                0                  412518
# ...                            ...                     ...
# 691421                           3                   26665
# 691422                           0                  552012
# 691423                           0                  370778
# 691424                       10667                  262068
# 691425                          32                   54850
#
#         community_id_leiden_es
# 0                            0
# 1                            1
# 2                            3
# 3                            5
# 4                       287201
# ...                        ...
# 691421                   25782
# 691422                  485042
# 691423                  331291
# 691424                  238435
# 691425                   52622
#
# [691426 rows x 9 columns]

# %%
sql5 = 'select community_id_fastgreedy_is, count(*) from nodes group by community_id_fastgreedy_is;'
result_df7 = cn.select_query_result_to_df(sql5)
result_df7
# Out:
#        community_id_fastgreedy_is  count(*)
# 0                               0    201900
# 1                               1    152391
# 2                               2    117700
# 3                            7636         3
# 4                               3    135933
# ...                           ...       ...
# 21365                       21206         2
# 21366                       21368         2
# 21367                       21281         2
# 21368                       21255         2
# 21369                       21313         2
#
# [21370 rows x 2 columns]

# %% [markdown]
# # comment, posts similarity (mentor, null)

# %%
result_df4 = pd.read_csv('random_similarity_2.csv')
result_df5 = pd.read_csv('random_similarity_4.csv')

# %%
np_result_list2 = []
np_result_list2.append(np.array(result_df2['comments_similarity'].tolist()))
np_result_list2.append(np.array(result_df4['random_comments_similarity'].tolist()))

legends = ['comments similarity', 'random comments similarity']
colors = ['red', 'blue']

draw_multiple_cdf_normalize_y(np_result_list2, 'CDF from 0(density) - Comments similarity by mentor(without ALL Moderators, Bots) & Null model', colors, 'similarity', legends, False)

# %%
np_result_list2.append(np.array(result_df5['random_comments_similarity'].tolist()))
colors = ['red', 'blue', 'green']
legends = ['comments similarity', 'random comments similarity (2 pair)', 'random comments similarity (4 pair)']
draw_multiple_cdf_normalize_y(np_result_list2, 'CDF from 0(density) - Comments similarity by mentor(without ALL Moderators, Bots) & all Null model', colors, 'similarity', legends, False)

# %%
np_result_list3 = []
np_result_list3.append(np.array(result_df3['posts_similarity'].tolist()))
np_result_list3.append(np.array(result_df4['random_posts_similarity'].tolist()))

colors = ['red', 'blue']
legends = ['posts similarity', 'random posts similarity']
draw_multiple_cdf_normalize_y(np_result_list3, 'CDF from 0(density) - Posts similarity by mentor(without ALL Moderators, Bots) & Null model', colors, 'similarity', legends, False)

# %%
np_result_list3.append(np.array(result_df5['random_comments_similarity'].tolist()))

colors = ['red', 'blue', 'green']
legends = ['posts similarity', 'random posts similarity (2 pair)', 'random posts similarity (4 pair)']
draw_multiple_cdf_normalize_y(np_result_list2, 'CDF from 0(density) - Posts similarity by mentor(without ALL Moderators, Bots) & all Null model', colors, 'similarity', legends, False)

# %%
np_result_list5 = []
np_result_list5.append(np.array(result_df6['indegree'].tolist()))
np_result_list5.append(np.array(result_df6['outdegree'].tolist()))

colors = ['red', 'blue']
legends = ['indegree', 'outdegree']
draw_multiple_cdf_normalize_y(np_result_list5, "CDF from 0(density) - Indegree, Outdegree distribution", colors, 'degree', legends, False)

# %%
draw_multiple_cdf_normalize_y(np_result_list5, "CDF from 0(density) - Indegree, Outdegree distribution (Log scale)", colors, 'degree', legends, True)

# %%
np_result_list6 = []
np_result_list6.append(np.array(result_df7['count(*)'].tolist()))

colors = ['blue']
legends = ['community members']
draw_multiple_cdf_normalize_y(np_result_list6, "CDF from 0(density) - # Community member distribution", colors, '# member', legends, False)

# %%
draw_multiple_cdf_normalize_y(np_result_list6, "CDF from 0(density) - # Community member distribution (Log scale)", colors, '# member', legends, True)
