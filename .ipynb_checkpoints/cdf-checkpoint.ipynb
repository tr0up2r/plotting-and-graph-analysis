# %%
# !pip install matplotlib
# !pip install scipy
# pip install seaborn

# %%
import pymysql.cursors
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
import connect_to_db as cn

# %%
# cdf plotting을 하기 위한 function.
def draw_cdf(np_result, n_bins, label, title, color):
    np_result = np.array(np_result, dtype=float)
    filename = title + '.png'

    plt.rcParams["figure.figsize"] = [15, 10]
    plt.rcParams["figure.autolayout"] = True

    count, bins_count = np.histogram(np_result, bins=n_bins)
    pdf = count / sum(count)
    cdf = np.cumsum(pdf)
    plt.plot(bins_count[1:], cdf, label="CDF", color=color)
    plt.xlabel(label, fontsize=12)
    plt.title(title, fontsize=18)
    plt.xscale('symlog')
    plt.savefig(filename, dpi=300)
    plt.show()

# %%
# pymysql을 이용한 db connection.
connection = cn.make_connection('connection.csv')

cursor1 = connection.cursor(pymysql.cursors.DictCursor)
cursor2 = connection.cursor(pymysql.cursors.DictCursor)
cursor3 = connection.cursor(pymysql.cursors.DictCursor)
cursor4 = connection.cursor(pymysql.cursors.DictCursor)

sql1 = 'select * from mentor;'
cursor1.execute(sql1)

sql2 = 'select * from mentor where comment_cnt < 10000;'
cursor2.execute(sql2)

sql3 = "select * from mentor where author not in ('greatyellowshark', 'gurneyhallack', 'aristapop', 'Pi25', 'SeriousSamStone', 'Umbresp', 'CUTIEJUDY', 'Imissmemom', 'aagee', 'noonches', 'Vientodecara', 'Jolojil', 'sciential84', 'AmazonPriceBot', 'AmputatorBot', 'AntiObnoxiousBot', 'ClickableLinkBot', 'converter-bot', 'CoolDownBot', 'FakespotAnalysisBot', 'HappyCakeBot', 'hotlinehelpbot', 'lerobinbot', 'LimbRetrieval-Bot', 'LinkifyBot', 'NoGoogleAMPBot', 'oofed-bot', 'PORTMANTEAU-BOT', 'Reddit-Book-Bot', 'remindditbot', 'RemindMeBot', 'RepostSleuthBot', 'RossGellerBot', 'sneakpeekbot', 'the_timezone_bot', 'timee_bot', 'tiny_smile_bot', 'TitleLinkHelperBot', 'wikipedia_answer_bot', ' wikipedia_text_bot', 'WikiTextBot', 'YoMommaJokeBot', '', 'AutoModerator');"
cursor3.execute(sql3)

sql4 = "select * from mentor where author not in ('greatyellowshark', 'gurneyhallack', 'aristapop', 'Pi25', 'SeriousSamStone', 'Umbresp', 'CUTIEJUDY', 'Imissmemom', 'aagee', 'noonches', 'Vientodecara', 'Jolojil', 'sciential84', 'AmazonPriceBot', 'AmputatorBot', 'AntiObnoxiousBot', 'ClickableLinkBot', 'converter-bot', 'CoolDownBot', 'FakespotAnalysisBot', 'HappyCakeBot', 'hotlinehelpbot', 'lerobinbot', 'LimbRetrieval-Bot', 'LinkifyBot', 'NoGoogleAMPBot', 'oofed-bot', 'PORTMANTEAU-BOT', 'Reddit-Book-Bot', 'remindditbot', 'RemindMeBot', 'RepostSleuthBot', 'RossGellerBot', 'sneakpeekbot', 'the_timezone_bot', 'timee_bot', 'tiny_smile_bot', 'TitleLinkHelperBot', 'wikipedia_answer_bot', ' wikipedia_text_bot', 'WikiTextBot', 'YoMommaJokeBot', '', 'AutoModerator', 'gurneyhallack', 'remyschnitzel', 'analemmaro', 'spud_simon_salem', 'one_moody_girl', 'VivaSisyphus', 'apparentlycompetent', 'zooline', 'yellowmix', 'TheYellowRose', 'Svataben', 'SQLwitch', 'circinia', 'sofar1776', 'Takei_Me');"
cursor4.execute(sql4)

# result가 dict 형태로 return.
result1 = cursor1.fetchall()
result2 = cursor2.fetchall()
result3 = cursor3.fetchall()
result4 = cursor4.fetchall()
connection.close()

# %%
result1_df = pd.DataFrame(result1)
result1_df
# Out:
#                       author  comment_cnt  mentee_cnt average_is_score  \
# 0                                  428466      125841          1.35895
# 1       _________________UWU            2           2          1.50000
# 2        ______________Blank            2           1          2.00000
# 3       _________-----------            4           1          2.00000
# 4       _________ez_________            1           1          1.00000
# ...                      ...          ...         ...              ...
# 595460      zzzzzsleepyzzzzz            3           2          1.33333
# 595461            zzzzzzarah            1           1          1.00000
# 595462           zzzzzzz____            3           3          1.00000
# 595463           zzzzzzzzzra            1           1          1.00000
# 595464           zzzzzzzzzz-            1           1          1.00000
#
#        average_es_score
# 0               1.82950
# 1               2.00000
# 2               1.50000
# 3               1.00000
# 4               2.00000
# ...                 ...
# 595460          2.00000
# 595461          3.00000
# 595462          2.00000
# 595463          3.00000
# 595464          2.00000
#
# [595465 rows x 5 columns]

# %%
result2_df = pd.DataFrame(result2)
result2_df
# Out:
#                       author  comment_cnt  mentee_cnt average_is_score  \
# 0       _________________UWU            2           2          1.50000
# 1        ______________Blank            2           1          2.00000
# 2       _________-----------            4           1          2.00000
# 3       _________ez_________            1           1          1.00000
# 4          _______Anon______            1           1          1.00000
# ...                      ...          ...         ...              ...
# 595458      zzzzzsleepyzzzzz            3           2          1.33333
# 595459            zzzzzzarah            1           1          1.00000
# 595460           zzzzzzz____            3           3          1.00000
# 595461           zzzzzzzzzra            1           1          1.00000
# 595462           zzzzzzzzzz-            1           1          1.00000
#
#        average_es_score
# 0               2.00000
# 1               1.50000
# 2               1.00000
# 3               2.00000
# 4               2.00000
# ...                 ...
# 595458          2.00000
# 595459          3.00000
# 595460          2.00000
# 595461          3.00000
# 595462          2.00000
#
# [595463 rows x 5 columns]

# %%
result3_df = pd.DataFrame(result3)
result3_df
# Out:
#                       author  comment_cnt  mentee_cnt average_is_score  \
# 0       _________________UWU            2           2          1.50000
# 1        ______________Blank            2           1          2.00000
# 2       _________-----------            4           1          2.00000
# 3       _________ez_________            1           1          1.00000
# 4          _______Anon______            1           1          1.00000
# ...                      ...          ...         ...              ...
# 595417      zzzzzsleepyzzzzz            3           2          1.33333
# 595418            zzzzzzarah            1           1          1.00000
# 595419           zzzzzzz____            3           3          1.00000
# 595420           zzzzzzzzzra            1           1          1.00000
# 595421           zzzzzzzzzz-            1           1          1.00000
#
#        average_es_score
# 0               2.00000
# 1               1.50000
# 2               1.00000
# 3               2.00000
# 4               2.00000
# ...                 ...
# 595417          2.00000
# 595418          3.00000
# 595419          2.00000
# 595420          3.00000
# 595421          2.00000
#
# [595422 rows x 5 columns]

# %%
result4_df = pd.DataFrame(result4)
result4_df
# Out:
#                       author  comment_cnt  mentee_cnt average_is_score  \
# 0       _________________UWU            2           2          1.50000
# 1        ______________Blank            2           1          2.00000
# 2       _________-----------            4           1          2.00000
# 3       _________ez_________            1           1          1.00000
# 4          _______Anon______            1           1          1.00000
# ...                      ...          ...         ...              ...
# 595403      zzzzzsleepyzzzzz            3           2          1.33333
# 595404            zzzzzzarah            1           1          1.00000
# 595405           zzzzzzz____            3           3          1.00000
# 595406           zzzzzzzzzra            1           1          1.00000
# 595407           zzzzzzzzzz-            1           1          1.00000
#
#        average_es_score
# 0               2.00000
# 1               1.50000
# 2               1.00000
# 3               2.00000
# 4               2.00000
# ...                 ...
# 595403          2.00000
# 595404          3.00000
# 595405          2.00000
# 595406          3.00000
# 595407          2.00000
#
# [595408 rows x 5 columns]

# %%
np_result1 = np.array(result1_df['average_is_score'].tolist())
draw_cdf(np_result1, 30, 'average_is_score', "CDF Mentor\'s average IS", 'limegreen')

# %%
np_result2 = np.array(result2_df['average_is_score'].tolist())
draw_cdf(np_result2, 30, 'average_is_score', "CDF Mentor's average IS (without '', AutoModerator)", 'violet')

# %%
np_result3 = np.array(result3_df['average_is_score'].tolist())
draw_cdf(np_result3, 30, 'average_is_score', "CDF Mentor's average IS (without all blank, moderators, bots)", 'dodgerblue')

# %%
np_result4 = np.array(result4_df['average_is_score'].tolist())
draw_cdf(np_result4, 30, 'average_is_score', "CDF Mentor's average IS (without ALL Moderators, Bots)", 'red')

# %%
np_result1 = np.array(result1_df['average_es_score'].tolist())
draw_cdf(np_result1, 30, 'average_es_score', "CDF Mentor\'s average ES", 'limegreen')

# %%
np_result2 = np.array(result2_df['average_es_score'].tolist())
draw_cdf(np_result2, 30, 'average_es_score', "CDF Mentor's average ES (without '', AutoModerator)", 'violet')

# %%
np_result3 = np.array(result3_df['average_es_score'].tolist())
draw_cdf(np_result3, 30, 'average_es_score', "CDF Mentor's average ES (without all blank, moderators, bots)", 'dodgerblue')

# %%
np_result4 = np.array(result4_df['average_es_score'].tolist())
draw_cdf(np_result4, 30, 'average_es_score', "CDF Mentor's average ES (without ALL Moderators, Bots)", 'red')

# %%
np_result1 = np.array(result1_df['comment_cnt'].tolist())
draw_cdf(np_result1, 30, 'comment_cnt', "CDF # Mentor\'s comment", 'limegreen')

# %%
np_result2 = np.array(result2_df['comment_cnt'].tolist())
draw_cdf(np_result2, 30, 'comment_cnt', "CDF # Mentor\'s comment (without '', AutoModerator)", 'violet')

# %%
np_result3 = np.array(result3_df['comment_cnt'].tolist())
draw_cdf(np_result3, 30, 'comment_cnt', "CDF # Mentor\'s comment (without all moderators, bots)", 'dodgerblue')

# %%
np_result4 = np.array(result4_df['comment_cnt'].tolist())
draw_cdf(np_result4, 30, 'comment_cnt', "CDF # Mentor\'s comment (without ALL Moderators, Bots)", 'red')

# %%
np_result1 = np.array(result1_df['mentee_cnt'].tolist())
draw_cdf(np_result1, 30, 'mentee_cnt', "CDF # Mentee per mentor", 'limegreen')

# %%
np_result2 = np.array(result2_df['mentee_cnt'].tolist())
draw_cdf(np_result2, 30, 'mentee_cnt', "CDF # Mentee per mentor (without '', AutoModerator)", 'violet')

# %%
np_result3 = np.array(result3_df['mentee_cnt'].tolist())
draw_cdf(np_result3, 30, 'mentee_cnt', "CDF # Mentee per mentor (without all moderators, bots)", 'dodgerblue')

# %%
np_result4 = np.array(result4_df['mentee_cnt'].tolist())
draw_cdf(np_result4, 30, 'mentee_cnt', "CDF # Mentee per mentor (without ALL Moderators, Bots)", 'red')
